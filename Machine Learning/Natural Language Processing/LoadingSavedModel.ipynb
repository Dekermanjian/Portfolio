# %%
import sparknlp
from pyspark.ml import Pipeline
from pyspark.sql import SparkSession
from sparknlp.annotator import *
from sparknlp.base import *
from sparknlp.common import *
import pyspark.sql.functions as F
from sparknlp.training import CoNLL

# %%
spark = sparknlp.start(gpu=False)

# %%
ner_model = PipelineModel.load("NER_model/")

# %%
# Normalize the text
normalizer = (
    Normalizer()
    .setInputCols(['token'])
    .setOutputCol('normalized')
    .setLowercase(False)
    .setCleanupPatterns(["[^\w\d\s]"])
)

# Get ELMo word embeddings
elmo = (
    ElmoEmbeddings.pretrained()
    .setInputCols("sentence", "normalized")
    .setOutputCol("elmo")
)
# Out:
# elmo download started this may take some time.
# Approximate size to download 334.1 MB
# [OK!]

# %%
test = CoNLL().readDataset(spark, 'Data/testingTextProcessed.txt')
test = normalizer.fit(test).transform(test)
test = elmo.transform(test)
test.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|            document|            sentence|               token|                 pos|               label|          normalized|                elmo|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |SECIMTools ( Sout...|[{document, 0, 12...|[{document, 0, 12...|[{token, 0, 9, SE...|[{pos, 0, 9, NNP,...|[{named_entity, 0...|[{token, 0, 9, SE...|[{word_embeddings...|
# |SECIMTools levera...|[{document, 0, 14...|[{document, 0, 14...|[{token, 0, 9, SE...|[{pos, 0, 9, NNP,...|[{named_entity, 0...|[{token, 0, 9, SE...|[{word_embeddings...|
# |Our method , name...|[{document, 0, 13...|[{document, 0, 13...|[{token, 0, 2, Ou...|[{pos, 0, 2, PRP$...|[{named_entity, 0...|[{token, 0, 2, Ou...|[{word_embeddings...|
# |The performance n...|[{document, 0, 12...|[{document, 0, 12...|[{token, 0, 2, Th...|[{pos, 0, 2, DT, ...|[{named_entity, 0...|[{token, 0, 2, Th...|[{word_embeddings...|
# |The analysis show...|[{document, 0, 92...|[{document, 0, 92...|[{token, 0, 2, Th...|[{pos, 0, 2, DT, ...|[{named_entity, 0...|[{token, 0, 2, Th...|[{word_embeddings...|
# |ChainRank provide...|[{document, 0, 14...|[{document, 0, 14...|[{token, 0, 8, Ch...|[{pos, 0, 8, NNP,...|[{named_entity, 0...|[{token, 0, 8, Ch...|[{word_embeddings...|
# |ChainRank impleme...|[{document, 0, 14...|[{document, 0, 14...|[{token, 0, 8, Ch...|[{pos, 0, 8, NNP,...|[{named_entity, 0...|[{token, 0, 8, Ch...|[{word_embeddings...|
# |Among 2000 ions r...|[{document, 0, 14...|[{document, 0, 14...|[{token, 0, 4, Am...|[{pos, 0, 4, IN, ...|[{named_entity, 0...|[{token, 0, 4, Am...|[{word_embeddings...|
# |Use MetaboAnalyst...|[{document, 0, 20...|[{document, 0, 20...|[{token, 0, 2, Us...|[{pos, 0, 2, VB, ...|[{named_entity, 0...|[{token, 0, 2, Us...|[{word_embeddings...|
# |We developed vali...|[{document, 0, 72...|[{document, 0, 72...|[{token, 0, 1, We...|[{pos, 0, 1, PRP,...|[{named_entity, 0...|[{token, 0, 1, We...|[{word_embeddings...|
# |VitisNet uses man...|[{document, 0, 21...|[{document, 0, 21...|[{token, 0, 7, Vi...|[{pos, 0, 7, JJ, ...|[{named_entity, 0...|[{token, 0, 7, Vi...|[{word_embeddings...|
# |VitisNet grounded...|[{document, 0, 13...|[{document, 0, 13...|[{token, 0, 7, Vi...|[{pos, 0, 7, NNP,...|[{named_entity, 0...|[{token, 0, 7, Vi...|[{word_embeddings...|
# |The molecular net...|[{document, 0, 17...|[{document, 0, 17...|[{token, 0, 2, Th...|[{pos, 0, 2, DT, ...|[{named_entity, 0...|[{token, 0, 2, Th...|[{word_embeddings...|
# |MetaBridge implem...|[{document, 0, 24...|[{document, 0, 24...|[{token, 0, 9, Me...|[{pos, 0, 9, NNP,...|[{named_entity, 0...|[{token, 0, 9, Me...|[{word_embeddings...|
# |MetaboAnalyst int...|[{document, 0, 97...|[{document, 0, 97...|[{token, 0, 12, M...|[{pos, 0, 12, NNP...|[{named_entity, 0...|[{token, 0, 12, M...|[{word_embeddings...|
# |This protocol pro...|[{document, 0, 31...|[{document, 0, 31...|[{token, 0, 3, Th...|[{pos, 0, 3, DT, ...|[{named_entity, 0...|[{token, 0, 3, Th...|[{word_embeddings...|
# |Although TOXcms b...|[{document, 0, 92...|[{document, 0, 92...|[{token, 0, 7, Al...|[{pos, 0, 7, IN, ...|[{named_entity, 0...|[{token, 0, 7, Al...|[{word_embeddings...|
# |In addition , fin...|[{document, 0, 52...|[{document, 0, 52...|[{token, 0, 1, In...|[{pos, 0, 1, IN, ...|[{named_entity, 0...|[{token, 0, 1, In...|[{word_embeddings...|
# |Here , introduce ...|[{document, 0, 95...|[{document, 0, 95...|[{token, 0, 3, He...|[{pos, 0, 3, RB, ...|[{named_entity, 0...|[{token, 0, 3, He...|[{word_embeddings...|
# |polyPK provides 1...|[{document, 0, 23...|[{document, 0, 23...|[{token, 0, 5, po...|[{pos, 0, 5, NN, ...|[{named_entity, 0...|[{token, 0, 5, po...|[{word_embeddings...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Apply the model onto the test data
predictions = ner_model.transform(test)

# %%
predictions = (
    predictions
    .select(F.explode(F.arrays_zip('token.result','label.result', 'ner.result', 'ner.metadata')).alias('cols'))
    .select(F.col('cols.0').alias('word'),
            F.col('cols.1').alias('Truth'),
            F.col('cols.2').alias('Prediction'),
            F.col('cols.3.confidence').alias('Confidence'))
    .dropna()
    .filter('Truth != "O"')
    .dropDuplicates(['word', 'Prediction'])
)

# %%
predictions = predictions.toPandas()

# %%
predictions[predictions.Prediction == 'T']
# Out:
#              word Truth Prediction Confidence
# 0           INMEX     T          T     0.9888
# 2         DrugViz     T          T     0.9784
# 4          jmzTab     T          T     0.8094
# 5        GridMass     T          T     0.8908
# 6      MassyTools     T          T     0.9008
# 7          OpenMS     T          T     0.9998
# 9          Escher     T          T     0.9971
# 10      ProfileDB     T          T     0.9924
# 13         Pathos     T          T     0.9715
# 16    MetaboQuant     T          T     0.9949
# 18         MarVis     T          T     0.7679
# 19         SIRIUS     T          T     0.9978
# 20      Lipid-Pro     T          T     0.9987
# 23       MetiTree     T          T     0.9998
# 28           XCMS     T          T      0.999
# 31      MetaboLab     T          T     0.9957
# 32         MZmine     T          T     0.9997
# 33            CMM     T          T     0.9938
# 35     LipidBlast     T          T      0.908
# 39        Unipept     T          T     0.9965
# 41            IPO     T          T     0.9946
# 44     PhenoMeNal     T          T     0.9991
# 47         DECOMP     T          T     0.5887
# 48      ChainRank     T          T     0.5105
# 49  BioContainers     T          T     0.9538
# 52  MetaboAnalyst     T          T        1.0
# 53         RIPPER     T          T     0.9898
# 56       MassTRIX     T          T     0.9789
# 57      OMICtools     T          T     0.9782
# 59       VitisNet     T          T     0.9995
# 60       MetMatch     T          T     0.9997
# 61         Grafta     T          T     0.9836
# 62  MarVis-Filter     T          T     0.9745
# 63         PROMIS     T          T     0.9292
# 65     SECIMTools     T          T     0.7371
# 66        TrackSM     T          T     0.8824
# 67         BATMAN     T          T     0.9974
